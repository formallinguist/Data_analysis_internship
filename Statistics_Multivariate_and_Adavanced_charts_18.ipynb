# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **`Multivariate Plots`**
#
# Multivariate analysis (MVA) is a Statistical procedure for analysis of data involving more than one type of measurement or observation. It may also mean solving problems where more than one dependent variable is analyzed simultaneously with other variables.

# %% [markdown]
# ## **`1. Stacked Bar Plot`**
#
# A stacked chart is a form of bar chart that shows the composition and comparison of a few variables, either relative or absolute, over time. Also called a stacked bar or column chart, they look like a series of columns or bars that are stacked on top of each other.

# %% [markdown]
# ### **`Stacked Chart Case Study`**
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ## **`2. Multiple Scatterplot`**
#
# A 3D scatter plot allows the visualization of multivariate data. This scatter plot takes multiple scalar variables and uses them for different axes in phase space. The different variables are combined to form coordinates in the phase space and they are displayed using glyphs and coloured using another scalar variable.

# %% [markdown]
# ### **`Scatterplot Case Study`**
#
# ![Specify_colors_scatter_plot_Seaborn_Python_1.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **`3. Multiple Lineplot`**
#
# A multiplot is a special type of plot that displays multiple Y fields over a single X field.
#
# **X field**. From the data, select the field to display on the horizontal x axis.
#
# **Y fields**. Select one or more fields from the data to display over the range of X field values.

# %% [markdown]
# ### **`Lineplot Case Study`**
#
# ![4wpmu.gif](data:image/gif;base64,...)

# %% [markdown]
# # **Bonus Advanced Charts**
#
# 1. Donut Chart
# 2.   Treemap
# 3. Background Map

# %%
# !pip install palettable
# Out:
# Collecting palettable
#   Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: palettable
# Successfully installed palettable-3.3.3

# %%
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7

# create data
names = ['groupA', 'groupB', 'groupC', 'groupD']
size = [12,11,3,30]

# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

from palettable.colorbrewer.qualitative import Pastel1_7
plt.pie(size, labels=names, colors=Pastel1_7.hex_colors)
p = plt.gcf()
p.gca().add_artist(my_circle)

# Show the graph
plt.show()

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
# # libraries
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
import pandas as pd

# Create a data frame with sample data
df = pd.DataFrame({'nb_people':[8,3,4,2], 'group':["group A", "group B", "group C", "group D"] })

# plot it
squarify.plot(sizes=df['nb_people'], label=df['group'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
# Import the pandas library
import pandas as pd

# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lon':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lat':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10, 12, 40, 70, 23, 43, 100, 43]
}, dtype=str)

data
# Out:
#       lon     lat            name value
# 0     -58     -34    Buenos Aires    10
# 1       2      49           Paris    12
# 2     145     -38       melbourne    40
# 3   30.32   59.93  St Petersbourg    70
# 4   -4.03    5.33         Abidjan    23
# 5  -73.57   45.52        Montreal    43
# 6   36.82   -1.29         Nairobi   100
# 7   -38.5  -12.97        Salvador    43

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_594a42d37bb7f49ee17f43553c44534b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_594a42d37bb7f49ee17f43553c44534b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_594a42d37bb7f49ee17f43553c44534b = L.map(
#                 &quot;map_594a42d37bb7f49ee17f43553c44534b&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb412c30919b58ba67578d3be0979ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.7.4)

# %%
for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
      popup=data.iloc[i]['name'],
   ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_594a42d37bb7f49ee17f43553c44534b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_594a42d37bb7f49ee17f43553c44534b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_594a42d37bb7f49ee17f43553c44534b = L.map(
#                 &quot;map_594a42d37bb7f49ee17f43553c44534b&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb412c30919b58ba67578d3be0979ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
#
#             var marker_3cb228bc0e2b7b281f296d66c3c444b1 = L.marker(
#                 [-34.0, -58.0],
#                 {}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
#
#         var popup_0184275848d6f56adb6a69c0ba3a0b75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dded76035231b1b06ae73dcc2c23634c = $(`&lt;div id=&quot;html_dded76035231b1b06ae73dcc2c23634c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buenos Aires&lt;/div&gt;`)[0];
#                 popup_0184275848d6f56adb6a69c0ba3a0b75.setContent(html_dded76035231b1b06ae73dcc2c23634c);
#
#
#
#         marker_3cb228bc0e2b7b281f296d66c3c444b1.bindPopup(popup_0184275848d6f56adb6a69c0ba3a0b75)
#         ;
#
#
#
#
#             var marker_0a177c925011483cad503e8b46459c73 = L.marker(
#                 [49.0, 2.0],
#                 {}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
#
#         var popup_ad2165a56a702d958a62cc9a56382151 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eacec5d423d0f57e4c2da149f0fc735b = $(`&lt;div id=&quot;html_eacec5d423d0f57e4c2da149f0fc735b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#                 popup_ad2165a56a702d958a62cc9a56382151.setContent(html_eacec5d423d0f57e4c2da149f0fc735b);
#
#
#
#         marker_0a177c925011483cad503e8b46459c73.bindPopup(popup_ad2165a56a702d958a62cc9a56382151)
#         ;
#
#
#
#
#             var marker_ff41902048b7c25825fee8115d3e48ce = L.marker(
#                 [-38.0, 145.0],
#                 {}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
#
#         var popup_761cea50fa12a88af404953dc6a88fd5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e836b107bb5ee4fb7bb5358de02c9f7 = $(`&lt;div id=&quot;html_0e836b107bb5ee4fb7bb5358de02c9f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;melbourne&lt;/div&gt;`)[0];
#                 popup_761cea50fa12a88af404953dc6a88fd5.setContent(html_0e836b107bb5ee4fb7bb5358de02c9f7);
#
#
#
#         marker_ff41902048b7c25825fee8115d3e48ce.bindPopup(popup_761cea50fa12a88af404953dc6a88fd5)
#         ;
#
#
#
#
#             var marker_c6e3ca41544006244443dd666bcf0594 = L.marker(
#                 [59.93, 30.32],
#                 {}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
#
#         var popup_e9824f9f357e5c16b471fd8da0617b3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b4a82de699fca004cdae0754496ee71 = $(`&lt;div id=&quot;html_6b4a82de699fca004cdae0754496ee71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Petersbourg&lt;/div&gt;`)[0];
#                 popup_e9824f9f357e5c16b471fd8da0617b3d.setContent(html_6b4a82de699fca004cdae0754496ee71);
#
#
#
#         marker_c6e3ca41544006244443dd666bcf0594.bindPopup(popup_e9824f9f357e5c16b471fd8da0617b3d)
#         ;
#
#
#
#
#             var marker_429207f0274cd82de226b9ceac025534 = L.marker(
#                 [5.33, -4.03],
#                 {}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
#
#
#         var popup_9c723d15b4571770922f5ddddd5771ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5df2d02d1c1319101287e8eb0aa1113d = $(`&lt;div id=&quot;html_5df2d02d1c1319101287e8eb0aa1113d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abidjan&lt;/div&gt;`)[0];
#                 popup_9c723d15b4571770922f5ddddd5771ee.setContent(html_5df2d02d1c1319101287e8eb0aa1113d);
#
#
#
#         marker_429207f0274cd82de226b9ceac025534.bindPopup(popup_9c723d15b4571770922f5ddddd5771ee)
#         ;
#
#
#
#
#             var marker_54647ac01674b41b94d2a771fccc21d8 = L.marker(
#                 [45.52, -73.57],
#                 {}
#             ).addTo(map_594a42d37bb7f49ee17f43553c44534b);
